# %% [markdown]
# # Domácí úkol č. 3 - 📈 Vizualizace ve strojovém učení od A do Z
#
# ## 📚 Data
# Pro tento úkol si studenti **zvolí vhodná data sami**. ☝️ Zvolená data by měla být veřejně dostupná a měla by simulovat nebo odpovídat nějaké reálné situaci (tzn. syntetická/vygenerovaná data neuvažujeme!). Data si vybírejte tak, abyste na nich byli schopni řešit klasifikační nebo regresní úlohu (tedy supervizované učení, přítomnost výstupní proměnné).
#
# **Pro odvážné:** Pokud se cítíte silní v kramflecích, můžete si zvolit i nesupervizovanou úlohu, např. shlukování.
#
# #### Tipy na data a řešení
# V souboru datasets_tips.md můžete najít tipy na různé veřejné weby s datasety.
#
# Inspiraci pro vypracování úkolu najdete v praktických ukázkách k přednáškám č. 8 a 9. Nicméně pouze zkopírovaný kód nebude hodnocen kladně.
#
# ☝️**Pozor!** Zkuste si zvolit trochu nápaditý dataset. Pokud si zvolíte dataset, který je často součástí tutoriálů (např. [Titanic dataset](https://www.tensorflow.org/datasets/catalog/titanic) nebo [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)), pro zisk plného počtu bodů budete muset zřejmě vynaložit větší úsilí při jeho kreativní a neotřelé prezentaci.
#
# ## Zadání
# > ☝️ Používejte **markdown buňky**! Zdůvodňujte všechny důležité kroky, popisujte vizualizace a co je z nich možné pozorovat. Za nepřehledný domácí úkol nebudou uděleny body.
#
# Za řádné průběžné komentování a vizuální prezentaci postupu a výsledků lze získat až 10 bodů. Notebook odevzdávejte po spuštění (tzn. včetně output buněk) a zkrontrolujte si, že se komentáře korektně zobrazují ('rendered file' na GitLabu ve vašem prohlížeči).
#
# Úkol můžete vypracovávat jako **jednotlivci** nebo **ve skupině maximálně 3 spolužáků**. Postup pro hodnocení skupiny najdete na stránkách předmětu [zde](https://courses.fit.cvut.cz/BI-VIZ/homeworks/index.html#_podrobnosti-k-hodnocen%C3%AD-třet%C3%ADho-úkolu).
#
# ### Pokyny pro vypracování
#
# 🙏 Pokud je to možné, v každém bodě vaší práce **využijte vizualizace** a svá zjištění komentujte.
#
# **📖 Vaše úloha:**
# 1. Popište klasifikační/regresní úlohu, kterou v rámci domácího úkolu budete řešit.
# 2. Uveďte zdroj, odkud čerpáte data. ⛔️ Pozn.: Pokud pracujete s lokálně uloženým datasetem, odevzdejte jej spolu s vyřešeným Jupyter Notebookem prostřednictvím GitLabu. To aby s daty mohl pracovat i vyučující při opravě.
#
# **✨ Dataset:**
# V této části máte za úkol načíst zvolená data a pomocí vizualizace a popisných statistik se s nimi seznámit. Dále je nutné data vhodným způsobem předzpracovat, abyste je mohli použít pro trénování modelu.
# 1. Načtěte si zvolený dataset a importujte potřebné knihovny. Volba knihoven je na vás.
# 2. Představte jednotlivé příznaky pomocí textových popisů.
# 3. Analyzujte dataset pomocí popisných statistik s využitím vhodných vizualizačních metod. Svá zjištění komentujte.
# 4. Vyšetřete chybějící hodnoty (včetně jejich reprezentace) a odlehlá pozorování. Opět využijte vizualizace, pokud je to možné a svá zjištění komentujte.
# 5. Proveďte všechny další úpravy, které jsou podle vás pro práci s vybraným datasetem nezbytné (např. konverze datových typů, odstranění duplicitních údajů, vytvoření nových příznaků, sjednocení reprezentace chybějících dat nebo jejich odstranění apod.). K úpravě datasetu se můžete v průběhu řešení úlohy vracet.
# 6. Připravte dataset tak, abyste na něm mohli natrénovat a vyhodnotit vybraný model (např. data vhodně rozdělte, pokud je to pro váš model a evaluaci nutné, rozdělení komentujte, nebo můžete využít křížovou validaci apod. -> znáte z BI-ML1).
#
# Z této části lze získat celkem 15 bodů.
#
# **⚙️Model:**
# V této části je vaším úkolem natrénovat model, který se pokusí vyřešit vaši úlohu. Zaměřte se především na vizualizaci jednotlivých kroků a výsledků, včetně komentářů. Kvalita modelu jako takového nebude hodnocena.
# 1. Pro svoji úlohu zvolte vhodný klasifikační/regresní model.
# 2. Zvolte si alespoň dva hyperparametry spolu s minimálně pěti hodnotami (zde může být i více, případně méně v závislosti na zvoleném hyperparametru), jejichž nejlepší kombinaci budete během trénování modelu hledat. Zvolené hyperparametry a jejich hodnoty popište.
# 3. Zvolte a popište ztrátovou funkci, pomocí které provedete vyhodnocení úspěšnosti modelu.
# 4. Daný model na datasetu natrénujte. Pokud to lze, model vizualizujte.
# 5. Vhodně vizualizujte a komentujte vliv jednotlivých kombinací hyperparamentrů na úspěšnost modelu. Uveďte nejlepší kombinaci.
# 6. Pokud to lze (!), vizualizujte rozhodovací hranici nejlepšího modelu pro vámi vybrané příznaky. Pokud to nelze, zdůvodněte, případně realizujte jinou viualizaci související s prezentací nejlepšího modelu.
# 7. Vhodně vizualizujte úspěšnost výsledného modelu - využijte alespoň dvě vizualizační metody.
#
# **Pro zájemce:** Pokud byste chtěli, můžete pro řešení úlohy použít modelů více a provést jejich srovnání (včetně ladění hyperparametrů a dalších kroků zmíněných výše).
#
# Z této části lze získat celkem 25 bodů.
#
# ### Bodové hodnocení
# Shrnutí bodů, které můžete nejvýše získat:
# - 10 bodů za průběžné komentáře a vizuální prezentaci postupu a výsledků,
# - 15 bodů za předzpracování a prezentaci dat,
# - 25 bodů za trénování a vyhodnocení modelu:
#
# Celkem lze za domácí úkol č. 3 získat maximálně 50 bodů (každý člen týmu nebo jednotlivec).

# %% [markdown]
# # HW03 - Vizualizace ve strojovém učení od A do Z
# ### Datový soubor o akademickém výkonu studentů
# * Dataset: https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data
# * V tomto úkolu se budeme snažit odhadnout, zda budou rodiče danného žáka spokojeni, čí nikoliv. Naše vysvětlovaná proměnná bude:
#     * **Parent School Satisfaction** – stupeň spokojenosti rodičů se školou, která nabývá hodnot:
#         * Yes
#         * No
# * Budeme porovnávat 2 modely:
#     * **Rozhodovací strom**
#     * **KNN**

# %% [markdown]
# ## Import základních balíčků
# Nejdříve naimportujeme potřebné balíčky.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math

from sklearn import metrics, datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterGrid
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy import stats

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Explorace a příprava dat
# Použijeme modul **pandas** k nahrání *xAPI-Edu-Data.csv* souboru do objektu DataFrame.
#
# Pomocí funkcí **shape()** a **head()** vypíšeme informace o načteném csv souboru.
#
# Nějaké hodnoty příznaků v souboru mohou být prázdné. To můžeme zjistit pomocí funkce **info()**, která nám ukáže počet *non-null* hodnot.
#
# Na konci si ještě vypíšeme počet duplicitních záznamů.

# %%
# Load xAPI-Edu-Data.csv into data
df = pd.read_csv("xAPI-Edu-Data.csv")
print("Shape of dataset\n-----------------")
display(df.shape)
print("First 10 records\n-----------------")
display(df.head(10))
print("Basic info\n-----------------")
display(df.info())
print("Number of uniques records\n-----------------")
display(df.nunique())
print("Number of NaN values")
display(df.isna().sum())
print("Number of duplicated records\n-----------------")
display(df.duplicated().sum())
# Out:
# Shape of dataset
# -----------------
# (480, 17)
# First 10 records
# -----------------
#   gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 5      F          KW       KuwaIT    lowerlevel    G-04         A    IT
# 6      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 7      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 8      F          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 9      F          KW       KuwaIT  MiddleSchool    G-07         B    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %% [markdown]
# ## Popis příznaků
# Dataset obsahuje:
# * 480 záznamů
# * 17 příznaků
# * 2 duplicitní záznamy - duplicitní záznam smažeme
# * datatypy:
#     * object
#     * int64
# Dataset neobsahuje:
# *  prázdné záznamy
#
# ### Atributy
#
# * Gender – pohlaví studenta (nominální: 'Male' nebo 'Female')
#
# * Nationality – státní příslušnost studenta (nominální: 'Kuwait'‚ 'Lebanon'‚ 'Egypt', 'SaudiArabia', 'USA', 'Jordan', 'Venezuela', 'Iran', 'Tunis', 'Morocco', 'Syria', 'Palestine', 'Iraq', 'Lybia')
#
# * Place of birth – místo narození studenta (nominální: 'Kuwait'‚ 'Lebanon'‚ 'Egypt', 'SaudiArabia', 'USA', 'Jordan', 'Venezuela', 'Iran', 'Tunis', 'Morocco', 'Syria', 'Palestine', 'Iraq', 'Lybia')
#
# * Educational Stages – student na vzdělávací úrovni (nominální: 'lowerlevel', 'MiddleSchool', 'HighSchool')
#
# * Grade Levels – známka studenta (nominální: 'G-01', 'G-02', 'G-03', 'G-04', 'G-05', 'G-06', 'G-07 ', 'G-08', 'G-09', 'G-10', 'G-11', 'G-12')
#
# * Section ID – student třídy (nominální: 'A', 'B', 'C')
#
# * Topic – téma kurzu (nominální: 'English', 'Spanish', 'French', 'Arabic', 'IT', 'Math', 'Chemistry', 'Biology', 'Science', 'History', 'Quran', 'Geology')
#
# * Semester – semestr školního roku (nominální: 'First', 'Second')
#
# * Parent – rodič odpovědný za žáka (nominální: 'mom', 'father')
#
# * Raised hand – kolikrát student zvedne ruku ve třídě (číslo: 0-100)
#
# * Visited resources – kolikrát student navštíví obsah kurzu (číslo: 0–100)
#
# * Viewing announcements – kolikrát student zkontroluje nová oznámení (numerické: 0-100)
#
# * Discussion groups – kolikrát se student účastní diskusních skupin (číslo: 0-100)
#
# * Parent Answering Survey – rodič odpovídal na průzkumy, které poskytuje škola nebo ne (nominální: 'Yes', 'No')
#
# * Parent School Satisfaction – stupeň spokojenosti rodičů se školou (nominální: 'Yes', 'No')
#
# * Student Absence Days – počet dní nepřítomnosti každého studenta (nominální: nad-7, pod-7)

# %% [markdown]
# Přejmenujeme názvy sloupců, aby byly názvy jednotné.

# %%
# create variable 'data' that is copy of 'df' ('data' will be used for classification, 'df' for 'visualization')
data = df

# Rename some columns for consistency
data = data.rename({
    'gender':'Gender',
    'NationalITy':'Nationality',
    'VisITedResources':'VisitedResources',
    'raisedhands':'RaisedHands'    
}, axis=1)

# %% [markdown]
# Z datasetu vybereme pouze *object* sloupce a ty rozdělíme podle počtu unikátních hodnot na **high_uniq** a **low_uniq**.
# * **high_uniq** - jména sloupců, co mají více než 3 unikátní hodnoty
# * **low_uniq** - jména sloupců, co mají 3 nebo méně unikátních hodnot

# %%
# Get columns with 3 or less unique records
low_uniq = []
# Get columns with more than 3 unique records
high_uniq = []
# Get columns which are only 'object' datatype
objects = []

for dt in data.dtypes.items():
    if dt[1] == object:
        objects.append(dt[0])

for i in objects:
    if len(data[i].unique()) <= 3:
        low_uniq.append(i)
    if len(data[i].unique()) > 3:
        high_uniq.append(i)
print("('object') Columns with low unique records: ")
display(low_uniq)
print("('object') Columns with high unique records: ")
display(high_uniq)
# Out:
# ('object') Columns with low unique records:
# ['Gender',
#  'StageID',
#  'SectionID',
#  'Semester',
#  'Relation',
#  'ParentAnsweringSurvey',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']
# ('object') Columns with high unique records:
# ['Nationality', 'PlaceofBirth', 'GradeID', 'Topic']

# %% [markdown]
# U všech příznaků z **low_uniq**, které mají pouze dvě možné hodnoty, změníme tyto hodnoty na 1 nebo 0.
# U všech příznaků z **low_uniq**, které mají pouze tři možné hodnoty, tyto hodnoty přeměníme buď na 2 nebo 1 nebo 0.
# Dále je přetypujeme na datový typ int.

# %%
# Change 2 unique values to 1 and 0
def changeToBinary ( column, one, zero):
    data[column] = data[column].replace([one,zero], [1,0])
    data[column] = data[column].astype(int)

changeToBinary( 'Gender', 'M', 'F')
changeToBinary( 'ParentAnsweringSurvey', 'Yes', 'No')
changeToBinary( 'ParentschoolSatisfaction', 'Good', 'Bad')
changeToBinary( 'StudentAbsenceDays', 'Above-7', 'Under-7' )
changeToBinary( 'Relation', 'Father', 'Mum' )
changeToBinary( 'Semester', 'S', 'F' )

# Change 3 unique values to 2, 1 and 0 
def changeToTrinary ( column, two, one, zero):
    data[column] = data[column].replace([two,one,zero], [2,1,0])
    data[column] = data[column].astype(int)
    
changeToTrinary('StageID', 'lowerlevel', 'MiddleSchool', 'HighSchool')
changeToTrinary('SectionID', 'A', 'B', 'C')
changeToTrinary('Class', 'M', 'L', 'H')

# %% [markdown]
# Jelikož si rozhodovací strom neumí poradit s nenumerickými příznaky, typ všech těchto příznaků nejdříve převedeme na "category" a následně na číselnou reprezentaci pomocí cat.codes.

# %%
data[high_uniq] = data[high_uniq].astype('category').apply(lambda x: x.cat.codes)

# %% [markdown]
# Použijeme metodu 'get_dummies' pro převod kategoriálních příznaků na dummy.

# %%
data = pd.get_dummies(data)

# %% [markdown]
# Pro kontrolu vypíšeme informace o datasetu.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    480 non-null    int64
#  1   Nationality               480 non-null    int8
#  2   PlaceofBirth              480 non-null    int8
#  3   StageID                   480 non-null    int64
#  4   GradeID                   480 non-null    int8
#  5   SectionID                 480 non-null    int64
#  6   Topic                     480 non-null    int8
#  7   Semester                  480 non-null    int64
#  8   Relation                  480 non-null    int64
#  9   RaisedHands               480 non-null    int64
#  10  VisitedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
#  13  ParentAnsweringSurvey     480 non-null    int64
# ...

# %% [markdown]
# A vidíme, že všechny příznaky jsou numerického typu (int).
#
# Jak jsme předtím zjistili, dataset obsahuje duplictní záznamy - přesněji 2 duplicity. Odstraníme je a pro kontrolu si vypíšeme, kolik záznamů bylo odstraněno.

# %%
beforeDropLen = len(df)
df.drop_duplicates(inplace=True)
print(f'Deleted {beforeDropLen - len(df)} duplicates from dataset.')
# Out:
# Deleted 2 duplicates from dataset.

# %% [markdown]
# Vytvoříme korelační matici.
# Z ní vidíme, že největší korelaci mají mezi sebou příznaky **StageID** a **GradeID**.
# * **StageID** = Grade Levels - známka studenta
# * **GradeID** = Section ID - student na vzdělávací úrovni

# %%
# Move explained variable to first position
data_corr = data
first_column = data_corr.pop('ParentschoolSatisfaction')
data_corr.insert(0, 'ParentschoolSatisfaction', first_column)

# Create correlation graph
fig, ax = plt.subplots(figsize=(16,6)) 
corelmat = data_corr.corr()
sns.heatmap(corelmat, annot=True, ax=ax)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Smažeme příznak **GradeID**.

# %%
# Remove column name 'GradeID'
data = data.drop(['GradeID'], axis=1)

# %% [markdown]
# Poměry příznaků.

# %%
ParentschoolSatisfaction_rate = data.ParentschoolSatisfaction.value_counts()
par_labels = ['Satisfied', 'Unsatisfied']

Gender_rate = data.Gender.value_counts()
Gender_labels = ['Male', 'Female']

Relation_rate = data.Relation.value_counts()
Relation_labels = ['Father', 'Mom']

fig = plt.figure(figsize=(20,6), constrained_layout=True)

ax1 = fig.add_subplot(1,3,1)
ax1.pie(ParentschoolSatisfaction_rate, labels=par_labels, autopct='%1.1f%%', colors=['red', 'green'])
ax1.set_title("The ratio of parents' satisfaction with the school")

ax2 = fig.add_subplot(1,3,2)
ax2.pie(Gender_rate, labels=Gender_labels, autopct='%1.1f%%', colors=['lightpink', 'lightskyblue'])
ax2.set_title("Student gender ratio")

ax3 = fig.add_subplot(1,3,3)
ax3.pie(Relation_rate, labels=Relation_labels, autopct='%1.1f%%', colors=['lightgreen', 'blue', 'orange'])
ax3.set_title("Gender ratio of parents responsible for the pupil")
# Out:
# Text(0.5, 1.0, 'Gender ratio of parents responsible for the pupil')

# %% [markdown]
# První graf nám popisuje poměr spokojenosti rodičů se školou. Vidíme, že více než 60% rodičů je spkojených se školou.
# Další graf říká, kolik procent žáků jsou muži a kolik ženy. Vidíme, že více je mužů (63.5%).
# A poslední graf vypovídá o pohlaví rodiče odpovědných za žáka - skoro 60% jsou otci a poté 42% jsou matky

# %% [markdown]
# # Rozdělení datasetu na trénovací, validační a testovací části

# %% [markdown]
# Data rozdělíme na *trénovací*, *testovací* a *validační* skupinu tak, aby 60% dat připadlo trénovací skupině, 20% validační a 20% testovací.
# Data se rozdělí pomocí funkce **train_test_split**, která to provede pseudonáhodně.

# %%
random_seed = 333

# Get rid of explained variable in Xdatasets and save explained variable to ydatasets
Xdata = data.drop("ParentschoolSatisfaction", axis = 1)
ydata = data.ParentschoolSatisfaction

# Split data: 60% for train data, 40% rest
Xtrain, Xrest, ytrain, yrest = train_test_split(Xdata, ydata, test_size=0.4, random_state=random_seed) 
print("Xtrain: ", Xtrain.shape, "\nytrain: ", ytrain.shape, "\nXtest: ", Xrest.shape, "\nytest: ", yrest.shape, "\n")

# Split rest of data (40%) into valid and test data, 50%/50%
Xval, Xtest, yval, ytest = train_test_split(Xrest, yrest, test_size=0.5, random_state=random_seed) 
print("Xval: ", Xval.shape, "\nyval: ", yval.shape, "\nXtest: ", Xtest.shape, "\nytest: ", ytest.shape)
# Out:
# Xtrain:  (288, 15)
# ytrain:  (288,)
# Xtest:  (192, 15)
# ytest:  (192,)
#
# Xval:  (96, 15)
# yval:  (96,)
# Xtest:  (96, 15)
# ytest:  (96,)

# %% [markdown]
# # Rozhodovací strom
# ### Najdeme nejlepší hyperparametry a naučíme model
#
# * Najdeme nejlepší hodnoty pro tyto hyperparametry:
#     * Depth = {1, 50}
#     * Criterion = {entropy, gini, log_loss}
#     * min_samples_leaf = {1, 4}
# * Naučíme model
#     * Použijeme nejlepší parametery a použijeme **.fit** na trénovací dataset
# * Zobrazíme výsledek
#     * Graf
#     * Přesnost - pomocí metody metrics.accuracy_score

# %%
# Find best hyperparameters (depths, criterions, min_samples_leaf)
get_param = {'max_depth': range(1,51),
             'criterion': ['entropy', 'gini', 'log_loss'],
             'min_samples_leaf': range(1,4)}
param_comb = ParameterGrid(get_param)

# Try all combinations (depth * criterions)
valid_acc = []
train_acc = []
for get_param in param_comb:
    dec_tree = DecisionTreeClassifier(max_depth=get_param['max_depth'],
                                      criterion=get_param['criterion'],
                                      min_samples_leaf=get_param['min_samples_leaf'])
    dec_tree.fit(Xtrain, ytrain)
    train_acc.append(metrics.accuracy_score(ytrain, dec_tree.predict(Xtrain)))
    valid_acc.append(metrics.accuracy_score(yval, dec_tree.predict(Xval)))

# Get best parameters from function above
best_param = param_comb[np.argmax(valid_acc)]
print("Best_params:", best_param, "\n")

# Train our model with best hyperparameters
dec_tree = DecisionTreeClassifier(**best_param)
dec_tree.fit(Xtrain, ytrain)

# Save our test prediction for later comparisons
tree_pred = metrics.accuracy_score(ytest, dec_tree.predict(Xtest))

# Plot grapth
fig, ax = plt.subplots(figsize=(16,5))
ax.plot(train_acc, 'o-', color='purple')
ax.plot(valid_acc, 'o-', color='blue')
ax.grid(axis='y', color='black', alpha=.5, linewidth=.5)
ax.set_title('Accuracy score with decision tree')
plt.xlabel('Hyperparameter index')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='center right')


# Print our accuracies
print('Accuracy score (train): {0:.4f}'.format(metrics.accuracy_score(ytrain, dec_tree.predict(Xtrain))))
print('Accuracy score (validation): {0:.4f}'.format(metrics.accuracy_score(yval, dec_tree.predict(Xval))))
print('Accuracy score (test): {0:.4f}'.format(metrics.accuracy_score(ytest, dec_tree.predict(Xtest))))
# Out:
# Best_params: {'min_samples_leaf': 1, 'max_depth': 5, 'criterion': 'gini'}
#
# Accuracy score (train): 0.8924
# Accuracy score (validation): 0.7812
# Accuracy score (test): 0.8125

# %% [markdown]
# Vykreslený strom.

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(16,8))
_ = tree.plot_tree(
    dec_tree, 
    feature_names=Xtrain.iloc[:,:].columns,  
    class_names=['0', '1'],
    filled=True,
    ax=ax
)

fig.savefig('tree.png')

# %% [markdown]
# # K-nejbližších sousedů
# ### Najdeme nejlepší hyperparametry a naučíme model
#
# * Najdeme nejlepší hodnoty pro tyto hyperparametry:
#     * n_neighbors = {3, 15}
# * Naučíme model
#     * Použijeme nejlepší parametery a použijeme **.fit** na trénovací dataset
# * Zobrazíme výsledek
#     * Graf
#     * Přesnost - pomocí metody metrics.accuracy_score

# %%
val_acc = []
train_acc = []

kneighbors = range(3,15)
for k in kneighbors:
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(Xtrain, ytrain)
    val_acc.append(clf.score(Xval, yval))
    train_acc.append(clf.score(Xtrain, ytrain))

# Plot grapth
plt.figure(figsize=(20,6))
plt.plot(kneighbors, train_acc,'o-', color='purple') #o: body, r: barva, -: spojení bodů linkou
plt.plot(kneighbors, val_acc,'ob-')
plt.xlabel('max_depth')
plt.ylabel('accuracy')
plt.legend(['train', 'validation'])

best_params_knn = np.argmax(val_acc) + 3
print('Best number of neighbours: ', best_params_knn, '\n')
best_val_acc_knn = val_acc[np.argmax(val_acc)]

clf = KNeighborsClassifier(n_neighbors = best_params_knn)
clf.fit(Xtrain, ytrain)

# Print our accuracies
print('Accuracy score (train): {0:.4f}'.format(metrics.accuracy_score(ytrain, clf.predict(Xtrain))))
print('Accuracy score (validation): {0:.4f}'.format(metrics.accuracy_score(yval, clf.predict(Xval))))
print('Accuracy score (test): {0:.4f}'.format(metrics.accuracy_score(ytest, clf.predict(Xtest))))
# Out:
# Best number of neighbours:  9
#
# Accuracy score (train): 0.7257
# Accuracy score (validation): 0.7396
# Accuracy score (test): 0.8021

# %% [markdown]
# Z grafu můžeme vypozorovat jakou přesnost dávají různé počty sousedů.

# %% [markdown]
# # Výběr nejlepšího modelu
# * Na závěr porovnáme přesnost **rozhodovacího stromu** na **validační** množině s přesností **KNN** na **validační** množině.
# * Vybereme lepší přesnost.
# * Zobrazíme finální přesnost na **testovaích** datech.

# %%
print('Accuracy score of decision tree (validation): {0:.4f}'.format(metrics.accuracy_score(yval, dec_tree.predict(Xval))))
print('Accuracy score of KNN (validation): {0:.4f}'.format(metrics.accuracy_score(yval, clf.predict(Xval))))
print("\n----------------------------------------------------\n")

dc = metrics.accuracy_score(yval, dec_tree.predict(Xval))
knn = metrics.accuracy_score(yval, clf.predict(Xval))

# from float to 'decimal' for easier comparison
a = round(dc*100, 0)
b = round(knn*100, 0)

if a >= b:
    print("Decision tree has better accuracy on validation dataset!")
    print(f"Accuracy score (test): {100*dc:.2f} %")
if b > a:
    print("KNN has better accuracy on validation dataset!")
    print(f"Accuracy score (test): {100*knn:.2f} %")
# Out:
# Accuracy score of decision tree (validation): 0.7812
# Accuracy score of KNN (validation): 0.7396
#
# ----------------------------------------------------
#
# Decision tree has better accuracy on validation dataset!
# Accuracy score (test): 78.12 %

# %% [markdown]
# Nejlepší validační hodnota je označena šipečkou, která na ni ukazuje

# %%
# Plot grapth
fig, ax = plt.subplots(figsize=(16,5))
ax.plot(train_acc, 'o-', color='purple')
ax.plot(valid_acc, 'o-', color='blue')
ax.grid(axis='y', color='black', alpha=.5, linewidth=.5)
ax.set_title('Accuracy score with decision tree')
plt.xlabel('Hyperparameter index')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='center right')

max_x = list(param_comb).index(best_param)
max_y = valid_acc[np.argmax(valid_acc)]
arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
plt.annotate(f'Max: ({max_x}, {max_y})', (max_x, max_y), 
            textcoords='offset points', xytext=(0, 20), ha='left', arrowprops=arrowprops)
# Out:
# Text(0, 20, 'Max: (162, 0.8125)')

# %% [markdown]
# Rozhodovací hranici nejlepšího modelu nelze vizualizovat, jelikož dataset má příliš mnoho příznaků.

# %% [markdown]
# Příprava dat pro vykreslení distribuce chyby.

# %%
def create_error_df(yreal, ypred, subset):
    df = pd.DataFrame()
    df['real'] = yreal
    df['predicted'] = ypred
    df['error'] = yreal - ypred
    df['set'] = subset
    return df
    
df = pd.concat([
    create_error_df(ytrain, dec_tree.predict(Xtrain), 'train'),
    create_error_df(yval, dec_tree.predict(Xval), 'validation'),
    create_error_df(ytest,dec_tree.predict(Xtest), 'test'),
])

display(df.head())
df.describe()
# Out:
#      real  predicted  error    set
# 262     1          1      0  train
# 326     0          0      0  train
# 226     0          0      0  train
# 331     1          0      1  train
# 242     0          0      0  train
#              real   predicted       error
# count  480.000000  480.000000  480.000000
# mean     0.608333    0.637500   -0.029167
# std      0.488632    0.481224    0.381163
# min      0.000000    0.000000   -1.000000
# 25%      0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    0.000000
# 75%      1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000

# %% [markdown]
# Pomocí **violin plotu** si vykreslíme distribuci chyby.

# %%
# seaborn default theme with dark grid
sns.set_theme()

fig, ax = plt.subplots(figsize=(16,8))
sns.violinplot(ax=ax, data=df, x='set', y='error', palette='Set2')

ax.set_ylabel('Error')
ax.set_xlabel('Set')
_ = ax.set_title('Error across sets')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9deabd9c-ecdf-41a4-b692-84d6a62447fd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
